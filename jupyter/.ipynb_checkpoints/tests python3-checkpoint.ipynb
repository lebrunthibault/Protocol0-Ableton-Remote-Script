# %%
from scipy.io.wavfile import read, write
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.axes import Axes
import struct

from speech_recognition.audio_data.AudioDataFactory import AudioDataFactory
from speech_recognition.audio_source.AudioFile import AudioFile

with AudioFile("./hello.wav") as source:
    audio = AudioDataFactory.make_from_source(source=source).frame_data

data = struct.unpack("h" * int(len(list(audio)) / 2), audio)
figure(figsize=(32, 8))
plt.plot(data)
# plt.xlabel("Sample index")
# plt.ylabel("WaveForm of Test Audio")
axes = plt.gca()
y_max = 16384 
axes.set_ylim([-y_max,y_max])
plt.text(x=0, y=y_max / 2,s="toto", fontsize=30)
plt.show()

# %%
import struct
from speech_recognition.audio_data.AudioDataFactory import AudioDataFactory
from speech_recognition.audio_source.AudioFile import AudioFile


with AudioFile("./hello.wav") as source:
    audio = list(AudioDataFactory.make_from_source(source=source).frame_data)
    
    
# def binarray(i):
#     while i:
#         yield i & 0xff
#         i = i >> 8

# print(list(binarray(0xABCD)))
# #[205, 171]

print(res)
# print(list(audio.frame_data)[0:4])
# Out:
# (298, 295, 298, 294, 296, 295, 292, 294, 292, 292, 293, 289, 290, 289, 289, 288, 289, 286, 288, 285, 286, 285, 285, 285, 283, 284, 284, 280, 284, 277, 282, 279, 276, 281, 273, 280, 273, 277, 273, 276, 272, 275, 272, 274, 270, 274, 270, 273, 272, 271, 271, 270, 268, 272, 268, 268, 268, 266, 267, 264, 267, 261, 268, 260, 263, 263, 261, 261, 262, 258, 263, 257, 261, 258, 258, 259, 256, 257, 257, 255, 256, 256, 252, 257, 251, 254, 252, 253, 250, 252, 249, 251, 248, 249, 249, 248, 250, 245, 249, 248, 245, 249, 240, 249, 244, 244, 247, 242, 246, 244, 243, 243, 244, 241, 242, 242, 240, 241, 241, 241, 242, 240, 239, 240, 240, 239, 240, 238, 237, 238, 235, 237, 235, 235, 235, 233, 233, 233, 231, 234, 230, 232, 229, 232, 227, 231, 226, 227, 229, 225, 228, 223, 228, 221, 230, 219, 228, 220, 225, 222, 222, 222, 219, 222, 218, 218, 218, 215, 217, 215, 215, 213, 217, 209, 217, 208, 215, 209, 210, 211, 207, 211, 206, 209, 207, 204, 208, 203, 207, 204, 204, 204, 203, 204, 201, 204, 199, 204, 199, 20
# ...

# %%
import struct
print(struct.pack("I", 100))
struct.unpack("4b", struct.pack("I", 100))
# Out:
# b'd\x00\x00\x00'
# (100, 0, 0, 0)

# %%
import struct
numbers = [0, 1, 2, 3]
import sys

tuples = list(zip(*[iter(numbers)] * 2))
print(tuples)

b = b""
l = []
for t in tuples:
    x, y = t
    l.append(n.to_bytes(2, sys.byteorder) + n.to_bytes(2, sys.byteorder))
    b += n.to_bytes(2, sys.byteorder)
print(b)
# number = 25
# b = number.to_bytes(4, 'little')
# print(b)
print(bytes([0, 1, 2, 3]))
bb = bytes([20, 21, 22, 23,20, 21, 22, 23])
print(bb)
res = struct.unpack("H" * 4, bb)
print(res)
print(list(res))
# Out:
# [(0, 1), (2, 3)]
# b'\x03\x00\x03\x00'
# b'\x00\x01\x02\x03'
# b'\x14\x15\x16\x17\x14\x15\x16\x17'
# (5396, 5910, 5396, 5910)
# [5396, 5910, 5396, 5910]

# %%
import struct
struct.pack("ddd", 1, 2, 3)
# Out:
# b'\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\x08@'

# %%
list(zip([1, 2, 3, 4]))
# Out:
# [(1,), (2,), (3,), (4,)]
